# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Import dataset
train = pd.read_csv('../data/tree_train.csv')
valid = pd.read_csv('../data/tree_valid.csv')
test = pd.read_csv('../data/tree_test.csv')

# attach train and valid
train = pd.concat([train, valid], axis=0)
train.head()
# Out:
#    Unnamed: 0  spacegroup  percent_atom_al  percent_atom_ga  percent_atom_in  \
# 0        1462         206           0.1875           0.2500           0.5625
# 1          19          12           0.2500           0.2500           0.5000
# 2         970         206           0.6250           0.3750           0.0000
# 3         214         194           0.6875           0.3125           0.0000
# 4        2217          33           0.9062           0.0312           0.0625
#
#    lattice_vector_1_ang  lattice_vector_2_ang  lattice_vector_3_ang  \
# 0                9.8238                9.8237                9.8238
# 1               12.2649                3.1889                6.3388
# 2                9.1418                9.1413                9.1413
# 3                6.1650                6.1648               23.5817
# 4                9.8901                8.4916                9.1232
#
#    lattice_angle_alpha_degree  lattice_angle_beta_degree  \
# 0                     90.0019                    90.0020
# 1                     90.0000                   105.0943
# 2                     90.0039                    90.0043
# 3                     90.0177                    89.9981
# 4                     90.0055                    90.0023
#
#    lattice_angle_gamma_degree  formation_energy_ev_natom  bandgap_energy_ev
# 0                     89.9976                     0.1833             1.3345
# 1                     90.0001                     0.2063             1.5596
# 2                     89.9967                     0.1051             3.6341
# 3                    120.0032                     0.2311             3.1668
# 4                     90.0012                     0.1067             4.0881

# %%
# Create features and labels & split training/crossvalidation/testing set

# list all features and labels
features = ['spacegroup', 'percent_atom_al', 'percent_atom_ga', 'percent_atom_in', 
            'lattice_vector_1_ang', 'lattice_vector_2_ang', 'lattice_vector_3_ang', 'lattice_angle_alpha_degree',
            'lattice_angle_beta_degree', 'lattice_angle_gamma_degree']
labels = ['formation_energy_ev_natom', 'bandgap_energy_ev']

xtrain = np.array(train[features])
ytrain = np.array(train[labels])
xtest  = np.array(test[features])
ytest  = np.array(test[labels])

# check the shape
print(xtrain.shape, ytrain.shape, xtest.shape, ytest.shape)
# Out:
# (1920, 10) (1920, 2) (480, 10) (480, 2)

# %%
# Training

# import models
from sklearn.ensemble import RandomForestRegressor

# initialize a random forest algorithm
rf = RandomForestRegressor(n_estimators=500, max_depth=9, random_state=42)

# fit to training data
rf.fit(xtrain,ytrain)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=9,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#            oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
# evaluate performance
print(rf.feature_importances_)

# training
print('###training###\n', 'score:', rf.score(xtrain, ytrain))
# test
print('###testing###\n', 'score:', rf.score(xtest, ytest))
ypred = rf.predict(xtest)

def rmsle(pred,target):
    return np.sqrt(np.square(np.log(pred + 1) - np.log(target + 1)).mean())

err = rmsle(ypred, ytest)
print('RMLSE:', err)
# Out:
# [0.01784604 0.53071217 0.10986013 0.0767838  0.0322058  0.16057798
#  0.02033427 0.02728639 0.02439342]
# ###training###
#  score: 0.97833361142404
# ###testing###
#  score: 0.9469718079023872
# RMLSE: 0.06887597075107584

# %%
# validation
from sklearn.model_selection import cross_val_score

scr = []
for j in range(10):
    n_trees = 500
    rf = RandomForestRegressor(n_estimators=n_trees, max_depth=j+1, random_state=42)
    scores = cross_val_score(rf, xtrain, ytrain, cv=5)
    scr.append(scores.mean())

# %%
depth = np.arange(1,11)
plt.plot(depth, scr)
scr
# Out:
# [0.5263928216008465,
#  0.6936513726190567,
#  0.8173275337691207,
#  0.8792725158769482,
#  0.9116917070431496,
#  0.9278575069397876,
#  0.9352943569970286,
#  0.9384786431648259,
#  0.9394456690571034,
#  0.9393969344721398]

# %%
from sklearn.model_selection import cross_val_score

scr = []
for j in range(10):
    depth = 9
    rf = RandomForestRegressor(n_estimators=n_trees, max_depth=9, random_state=42)
    scores = cross_val_score(rf, xtrain, ytrain, cv=5)
    scr.append(scores.mean())

# %%
fin_test = pd.read_csv('../data/official_test.csv')
fin_test.head()
# Out:
#    id  spacegroup  number_of_total_atoms  percent_atom_al  percent_atom_ga  \
# 0   1          33                   80.0           0.1875           0.4688
# 1   2          33                   80.0           0.7500           0.2500
# 2   3         167                   30.0           0.6667           0.1667
# 3   4          12                   80.0           0.5625           0.4375
# 4   5          12                   80.0           0.1875           0.5000
#
#    percent_atom_in  lattice_vector_1_ang  lattice_vector_2_ang  \
# 0           0.3438               10.5381                9.0141
# 1           0.0000                9.8938                8.5014
# 2           0.1667                4.9811                4.9808
# 3           0.0000               24.3370                6.0091
# 4           0.3125               24.6443                6.2906
#
#    lattice_vector_3_ang  lattice_angle_alpha_degree  \
# 0                9.6361                     89.9997
# 1                9.1298                     90.0038
# 2               13.4799                     89.9900
# 3                5.7620                     89.9995
# 4                6.1589                     90.0000
#
#    lattice_angle_beta_degree  lattice_angle_gamma_degree
# 0                    90.0003                     90.0006
# 1                    90.0023                     90.0015
# 2                    90.0109                    120.0014
# 3                   103.8581                     90.0002
# 4                   104.5929                     90.0001

# %%
final_test  = np.array(fin_test[features])
rf = RandomForestRegressor(n_estimators=500, max_depth=9, random_state=42)
rf.fit(xtrain,ytrain)
final_pred = rf.predict(final_test)

# %%
d = {labels[0]:final_pred[:,0], labels[1]:final_pred[:,1]}
final = pd.DataFrame(data=d)
submission = final.to_csv('submission.csv')

# %%
# initialize a random forest algorithm
rf1 = RandomForestRegressor(n_estimators=500, max_depth=9, random_state=42)

# fit to training data
rf1.fit(xtrain,ytrain[:,0])

rf2 = RandomForestRegressor(n_estimators=500, max_depth=9, random_state=42)
rf2.fit(xtrain,ytrain[:,1])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=9,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#            oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
y1 = rf1.predict(xtest)
y2 = rf2.predict(xtest)
err1 = rmsle(y1, ytest[:,0])
err2 = rmsle(y2, ytest[:,1])
print(err1, err2)
# Out:
# 0.03269456399667549 0.09122147356569124

# %%
rf.estimators_
# Out:
# [DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1608637542, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1273642419, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1935803228, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=787846414, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=996406378, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1201263687, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=423734972, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=415968276, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=670094950, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1914837113, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=669991378, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=429389014, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=249467210, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1972458954, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1572714583, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1433267572, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=434285667, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=613608295, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=893664919, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=648061058, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=88409749, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=242285876, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=2018247425, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=953477463, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1427830251, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1883569565, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=911989541, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=3344769, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=780932287, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=2114032571, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=787716372, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=504579232, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1306710475, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=479546681, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=106328085, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=30349564, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1855189739, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=99052376, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1250819632, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=106406362, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=480404538, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1717389822, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=599121577, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=200427519, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1254751707, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=2034764475, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1573512143, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=999745294, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1958805693, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=389151677, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1224821422, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=508464061, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=857592370, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1642661739, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=61136438, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=2075460851, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=396917567, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=2004731384, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=199502978, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1545932260, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=461901618, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=774414982, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=732395540, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1934879560, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=279394470, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=56972561, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1927948675, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1899242072, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1999874363, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=271820813, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1324556529, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1655351289, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1308306184, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=68574553, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=419498548, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=991681409, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=791274835, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1035196507, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1890440558, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=787110843, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=524150214, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=472432043, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=2126768636, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1431061255, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=147697582, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=744595490, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1758017741, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1679592528, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1111451555, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=782698033, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=698027879, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1096768899, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1338788865, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1826030589, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=86191493, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=893102645, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=200619113, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=290770691, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=793943861, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=134489564, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=2016850622, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1470101905, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1181686489, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1931679275, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1887633569, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1697157321, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1695770557, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1832485859, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=420477197, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=976125790, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1811936047, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1402481934, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=380072391, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=302554573, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=841739990, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=89482491, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=194249720, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1980718781, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1397283111, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1479761620, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1669356239, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1062231788, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1165435217, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=170476398, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1411916852, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=372593431, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1532243865, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1998256344, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1206604539, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=459708603, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=183378299, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1185407468, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=605264936, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1272485020, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1297926158, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=709816108, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=320192576, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=67157848, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=2091163462, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1818495496, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1169282391, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1696003200, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=853477355, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1260522119, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=23717335, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=60472382, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1354896522, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=854021618, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
# ...
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1047927533, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=385992349, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=2031564837, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=2056829157, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1688341868, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=2090541618, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1683827125, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1744180999, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=563236122, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1865709594, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1266204897, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1503575316, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=11326237, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=623214176, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=330299675, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=725523310, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=2115347391, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1564087776, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=838562244, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=988638203, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=955424572, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=2144019247, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1205908114, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=309255683, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=104436258, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1153430719, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=624798768, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=187276799, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=760684560, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=2124078251, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1891755227, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=2018396317, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1949608412, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1200702509, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1781828980, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1647094277, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1589819490, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1063944059, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=66385640, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1945928740, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1839614231, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1420561756, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1839036912, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=226623789, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=2004267188, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=310493790, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1991232610, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=2063008443, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1516164064, splitter='best'),
#  DecisionTreeRegressor(criterion='mse', max_depth=9, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=323609715, splitter='best')]

# %%
from sklearn import tree
t = tree.DecisionTreeRegressor()
t = t.fit(xtrain,ytrain)
tree.export_graphviz(t, out_file='tree.dot')
